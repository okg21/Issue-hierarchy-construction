# %%
import pandas as pd

def read_csvs(repo_name):
    clustered_data = pd.read_csv('data/clustered_data_' + repo_name + '.csv')
    epic_data = pd.read_csv('data/epic_data_' + repo_name + '.csv')
    return clustered_data, epic_data

# %%
clustered_data, epic_data = read_csvs('ckeditor5')
clustered_data.head()
# Out:
#   Repo Owner  Repo Name                                        Issue Title  \
# 0   ckeditor  ckeditor5  There should be an empty paragraph in the newl...
# 1   ckeditor  ckeditor5                             Typings for TypeScript
# 2   ckeditor  ckeditor5                                      Table feature
# 3   ckeditor  ckeditor5                                      Style feature
# 4   ckeditor  ckeditor5  Feature Request: Cycle Through List Styles on ...
#
#                                           Issue Body      Author    Assignees  \
# 0  When you create an editor, but not call `setDa...     pjasiun           []
# 1  Hi,\r\n\r\nI'm currently using ckeditor5 in Ty...    ssougnez           []
# 2  We plan to bootstrap the table feature very so...     Reinmar  ['jodator']
# 3  I would like to propose the **Styles** feature...      fredck           []
# 4  Rather than supporting "ordered list" and "ord...  duracell80           []
#
#                                             Comments  \
# 0  [{'body': 'As a matter of fact, that paragraph...
# 1  [{'body': "Quoting myself from https://github....
# 2  [{'body': 'One of the first things we have to ...
# 3  [{'body': 'As much as I understand the idea, I...
# 4  [{'body': '> This isn\'t something a designer ...
#
#                                               Labels Issue State  \
# 0       ['resolution:duplicate', 'type:improvement']      CLOSED
# 1        ['type:feature', 'support:2', 'squad:core']      CLOSED
# 2           ['type:feature', 'domain:accessibility']      CLOSED
# 3  ['status:discussion', 'type:feature', 'support...        OPEN
# 4                           ['resolution:duplicate']      CLOSED
#
#    Issue Number        References  \
# 0           331                []
# 1           504  ['504', '11704']
# 2           610                []
# 3           648                []
# 4          1028                []
#
#                                        Combined Text  Cluster  \
# 0  There should be an empty paragraph in the newl...        6
# 1  Typings for TypeScript Hi,\r\n\r\nI'm currentl...        1
# 2  Table feature We plan to bootstrap the table f...       23
# 3  Style feature I would like to propose the **St...       16
# 4  Feature Request: Cycle Through List Styles on ...        1
#
#    GroundTruthCluster
# 0                   0
# 1                  21
# 2                   5
# 3                   7
# 4                   1

# %%
import openai
from openai_key import OPEN_AI_KEY

# Function to concatenate issue data into a single string with flags
def concatenate_issue_data(group):
    # Create a string for each row and then concatenate them with a space
    return ' '.join(
        f"<TITLE> {row['Issue Title']} <BODY> {row['Issue Body']}" +
        f"<LABELS> {row['Labels']} <ISSUE_NUMBER> {row['Issue Number']}"
        for _, row in group.iterrows()
    )

# Group the DataFrame by 'GroundTruthCluster' and concatenate the data
concatenated_issues = clustered_data.groupby('Cluster').apply(concatenate_issue_data).to_dict()

# OpenAI API key setup (make sure to use your own API key)
openai.api_key = OPEN_AI_KEY


def create_tasks_section(dataframe, cluster_id, repo_name, repo_owner):
    # Filter the DataFrame for the specified cluster
    cluster_issues = dataframe[dataframe['Cluster'] == cluster_id]

    # Create tasks section with hyperlinks for each issue
    tasks_section = "\n".join(
        f"- [ ] [{row['Issue Title']}](https://github.com/{repo_owner}/{repo_name}/issues/{row['Issue Number']})\n"
        for _, row in cluster_issues.iterrows()
    )
    return tasks_section

def create_openai_query(issues_string):
    # Format the query string
    query = (
        "You are an expert on software project management. You are given the issue data:\n\n"
        f"{issues_string}\n\n"
        "Given the issues above, create an epic issue that encloses all the issues."
        "Create a <BODY> section that gives the description for the epic issue very briefly. Don't list the issues in the <BODY> section."
        "Don't give too much information in the <BODY> section, just enough to describe the epic issue."
        "Then provide a <TITLE> and <LABELS> for the epic issue."
        "Give your output in the format of <TITLE>: Epic Issue Title<BODY>: Epic issue body<LABELS>: Labels."
        "Give newlines when necessary."
    )

    # Make a request to the OpenAI API
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[{"role": "user", "content": query}],
        #prompt=query,
        max_tokens=1024
    )
    return response.choices[0].message.content

# %%
def create_epics(clustered_data):
    #get repo name and owner
    repo_name, repo_owner = clustered_data.iloc[0][['Repo Name', 'Repo Owner']]

    #get number of clusters
    cluster_ids = clustered_data['Cluster'].unique()
    predicted_epics = pd.DataFrame(columns=['Cluster', 'Epic Title', 'Epic Body', 'Epic Labels', 'Task Section'])

    for id in cluster_ids:
        tasks_section = create_tasks_section(clustered_data, id, repo_name, repo_owner)
        # Assuming 'concatenated_issues' contains the issues data as a string
        issues_string = concatenated_issues[id]
        response = create_openai_query(issues_string)
        
        #parse the output
        title = response.split('<TITLE>')[1].split('<BODY>')[0]
        body = response.split('<BODY>')[1].split('<LABELS>')[0]
        labels = response.split('<LABELS>')[1].split('\n-[]')[0]

        predicted_epics = predicted_epics.append({'Cluster': id, 'Epic Title': title, 'Epic Body': body, 'Epic Labels': labels, 'Task Section': tasks_section}, ignore_index=True)
    return predicted_epics

# %%
predicted_epics = create_epics(clustered_data)

# %%
predicted_epics
# Out:
#    Cluster                                         Epic Title  \
# 0        6   Epic Issue: Software Project Management Impro...
# 1        1   Epic Issue: TypeScript Typings and List Style...
# 2       23         Epic Issue: Table Feature Implementation\n
# 3       16                        Styles Feature Epic Issue\n
# 4       10   Epic: Improve CKEditor 5 Image Feature Compat...
# 5       21   Software Project Management Epic: Improve Sof...
# 6       22   Epic Issue: Improve CKEditor5 Navigation, Tab...
# 7       24   Epic Issue: Alignment Dropdown and Table Sele...
# 8        9   Epic Issue: Enhancements and Fixes for CKEdit...
# 9       13          Epic Issue: Software Project Management\n
# 10      25   Epic Issue: Improve Table Selection and Handl...
# 11       3   Epic Issue: Table Selection and Manipulation ...
# 12       0   Epic Issue: Table Properties Alignment and Se...
# 13       7   Epic Issue: Improve Software Project Manageme...
# 14      29         Create Epic Issue for Table Enhancements\n
# 15      20           Epic Issue: Fix Cell Selection Logic\n\n
# 16      28            Code Coverage and Monorepo Epic Issue\n
# 17       2   Epic Issue: Improve CKEditor5 Drag & Drop Fun...
# 18      15   Epic Issue: Update CKEditor Documentation and...
# 19      27   Migrate and Stabilize CKEditor5 Input Plugin ...
# 20      26                     Inline images - Epic Issue\n\n
# 21      30   Epic Issue: Improvement of Search Functionali...
# 22       5   Epic Issue: Integration and Style Enhancements\n
# 23      31   Epic Issue: Improvement for Image Handling an...
# 24      17   [Epic] Integration and Clean up for Style Dro...
# 25      19   Epic Issue: Improve Drag & Drop Functionality...
# 26      11   Integration and Improvement of Styles Feature...
# 27      12           [Epic] TypeScript-related Enhancements\n
# 28       4    Epic Issue: Cannot set block style on table\n\n
# 29       8   Epic Issue: Software Project Management for L...
# 30      14   [EPIC] Add types to DLLs\n<LABELS> ['squad:co...
# 31      18   Epic Issue: Stale Issues and PRs Management\n...
#
#                                             Epic Body  \
# 0    This epic issue aims to address multiple soft...
# 1    This epic issue aims to address two areas of ...
# 2    Implementing the table feature is a critical ...
# 3    This epic issue encompasses various issues re...
# 4    This epic aims to improve the image feature i...
# 5    This epic aims to improve the modularity and ...
# 6    This epic issue aims to address multiple impr...
# 7    This epic issue aims to address several issue...
# 8    This epic issue aims to address several enhan...
# 9    This epic issue encompasses multiple issues r...
# 10   This epic issue aims to improve the table sel...
# 11   Provide a description of the epic issue very ...
# 12   This epic issue aims to address various table...
# 13   This epic issue aims to improve software proj...
# 14   This epic issue aims to address and enhance t...
# 15   This epic issue aims to address the problem w...
# 16   This epic issue aims to address code coverage...
# 17   This epic aims to improve the drag and drop f...
# 18   This epic issue aims to improve the CKEditor ...
# 19   Migrating the Input plugin to the beforeInput...
# 20   This epic issue aims to address the requireme...
# 21   This epic issue aims to enhance the search fu...
# 22   This epic issue aims to address multiple issu...
# 23   This epic issue encompasses several improveme...
# 24   This epic issue aims to address the missing i...
# 25   This epic issue aims to address the following...
# 26   Enhance the styles feature in CKEditor to imp...
# 27   This epic issue aims to address several TypeS...
# 28   The epic issue is about the inability to set ...
# 29   This epic issue aims to address two separate ...
# 30   This epic issue aims to add type declarations...
# 31   This epic issue aims to implement a system fo...
#
#                                           Epic Labels  \
# 0                         ['type:epic', 'squad:core']
# 1                                       ['type:epic']
# 2               ['type:epic', 'domain:accessibility']
# 3    ['type:epic', 'domain:ui/ux', 'status:discuss...
# 4    ['type:task', 'package:core', 'domain:compati...
# 5          ['type:epic', 'status:open', 'squad:core']
# 6   : Epic, Improvement, Bug Fix, Performance, Nav...
# 7                         ['type:epic', 'squad:core']
# 8                         ['type:epic', 'squad:core']
# 9                       : ['type:epic', 'squad:core']
# 10   ['type:epic', 'package:table', 'domain:access...
# 11                     ['type:epic', 'package:table']
# 12     ['type:epic', 'package:table', 'domain:ui/ux']
# 13   ['type:epic', 'squad:core', 'domain:ui/ux', '...
# 14   ['type:epic', 'package:table', 'package:find-...
# 15                      ['type:bug', 'package:table']
# 16                                      ['type:epic']
# 17                        ['type:epic', 'squad:core']
# 18   ['type:epic', 'team:devops', 'team:core', 'do...
# 19   ['type:epic', 'package:typing', 'package:clou...
# 20                        ['type:epic', 'squad:core']
# 21   ['type:epic', 'domain:ui/ux', 'squad:features...
# 22   ['type:epic', 'squad:core', 'package:style', ...
# 23                  ['type:improvement', 'support:2']
# 24                                      ['type:epic']
# 25                         ['type:bug', 'squad:core']
# 26       ['type:epic', 'squad:core', 'package:style']
# 27                                      ['type:epic']
# 28       \n- type:epic\n- squad:core\n- package:style
# 29                                               Epic
# 30   ['squad:core']\n\n<BODY> This epic issue aims...
# 31   ['type:epic', 'squad:devops']\n\n<BODY> This ...
#
#                                          Task Section
# 0   - [ ] [There should be an empty paragraph in t...
# 1   - [ ] [Typings for TypeScript](https://github....
# 2   - [ ] [Table feature](https://github.com/ckedi...
# 3   - [ ] [Style feature](https://github.com/ckedi...
# 4   - [ ] [[Proposal] Provide TS type checking bas...
# 5   - [ ] [Conversion from simple model to complex...
# 6   - [ ] [Implement a custom navigation through t...
# 7   - [ ] [The alignment dropdown has unnecessary ...
# 8   - [ ] [Setting image height and width](https:/...
# 9   - [ ] [Placeholders for non-restricted areas i...
# 10  - [ ] [Table selection with keyboard](https://...
# 11  - [ ] [Review behavior of existing features on...
# 12  - [ ] [Align table properties UI to multi-rang...
# 13  - [ ] [Table selection does not cooporate with...
# 14  - [ ] [Enable table selection as core table fe...
# 15  - [ ] [It should be possible to make selection...
# 16  - [ ] [Code coverage for monorepo](https://git...
# 17  - [ ] [Adjust docs for monorepo](https://githu...
# 18  - [ ] [Revisit "Custom builds" and "Installing...
# 19  - [ ] [Migrate the Input plugin to the beforeI...
# 20  - [ ] [Inline images - MVP step 2](https://git...
# 21  - [ ] [Action when there are no more search re...
# 22  - [ ] [Integrate find and replace plugin with ...
# 23  - [ ] [Image plugin doesn't handle width/heigh...
# 24  - [ ] [[Style dropdown] Missing integration wi...
# 25  - [ ] [Remove format does not remove styles ap...
# 26  - [ ] [[Style dropdown] Integration with docum...
# 27  - [ ] [[TS] Revise code style guide to cover T...
# 28  - [ ] [Cannot set block style on table](https:...
# 29  - [ ] [New list plugin doesn't convert subsequ...
# 30  - [ ] [[TS] Add types to DLLs](https://github....
# 31  - [ ] [Find issues matching criteria to mark t...

# %%
predicted_epics.to_csv('data/predicted_epics_ckeditor5.csv', index=False)
