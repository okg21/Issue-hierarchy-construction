# %%
import pandas as pd

#read and display the data
df = pd.read_csv('ckeditor5_issues.csv')
#drop repo owner and repo name columns
df.drop(['Repo Owner', 'Repo Name'], axis=1, inplace=True)

df.head()
# Out:
#                      Issue Title  \
# 0  Introduce tests and Bender.js
# 1          Introduce the AMD API
# 2      Introduce CKEDITOR.create
# 3        Plugins path resolution
# 4    Introduce the build process
#
#                                           Issue Body  Author   Assignees  \
# 0  The infrastructure for testing must be created...  fredck  ['fredck']
# 1  The AMD API must be introduced according to [i...  fredck          []
# 2  Introduce the `CKEDITOR.create` method and the...  fredck          []
# 3  The RequireJS "plugin" plugin must be created ...  fredck          []
# 4            The build process must be introduced.\n  fredck          []
#
#                                             Comments                Labels  \
# 0                                                 []  ['type:improvement']
# 1  [{'body': 'This includes the introduction of t...  ['type:improvement']
# 2  [{'body': 'Because of #19, nothing must be don...  ['type:improvement']
# 3  [{'body': 'This is prototyped here:\nhttps://g...  ['type:improvement']
# 4  [{'body': 'This has been prototyped here:\nhtt...  ['type:improvement']
#
#   Issue State  Issue Number
# 0      CLOSED           1.0
# 1      CLOSED           2.0
# 2      CLOSED           3.0
# 3      CLOSED           4.0
# 4      CLOSED           5.0

# %%
#github issue link format is https://github.com/ckeditor/ckeditor5/issues/8666
#https://github.com/repo_owner/repo_name/issues/issue_number
#define a regular expression to extract issue number from a given text
import re
import json

def extract_issue_ref(text):
    if not isinstance(text, str):
        # If text is not a string, make it a string
        text = str(text)
    issue_url_regex = r'https://github\.com/([\w-]+)/([\w-]+)/issues/(\d+)'
    matches = re.findall(issue_url_regex, text)
    issue_numbers = [match[2] for match in matches]
    return issue_numbers

# %%
# Apply the function to each row for 'Issue Body' and 'Comments' and combine the results, ensuring uniqueness
df['References'] = df.apply(lambda row: str(list(set(extract_issue_ref(row['Issue Body'])) | 
                                             set(extract_issue_ref(row['Comments'])))), axis=1)

#TO-DO Remove the comment references for the epic issuesas

df
# Out:
#                                              Issue Title  \
# 0                          Introduce tests and Bender.js
# 1                                  Introduce the AMD API
# 2                              Introduce CKEDITOR.create
# 3                                Plugins path resolution
# 4                            Introduce the build process
# ...                                                  ...
# 12451          Make the `UpcastEvent` definition visible
# 12452  Linter error when changing `augmentation.ts` f...
# 12453  CKEditor In Vue3 - CKEditorError: ckeditor-dup...
# 12454               ListProperties not showin in Toolbar
# 12455       Changelog generator - ability to format date
#
#                                               Issue Body        Author  \
# 0      The infrastructure for testing must be created...        fredck
# 1      The AMD API must be introduced according to [i...        fredck
# 2      Introduce the `CKEDITOR.create` method and the...        fredck
# 3      The RequireJS "plugin" plugin must be created ...        fredck
# 4                The build process must be introduced.\n        fredck
# ...                                                  ...           ...
# 12451  ## Provide a description of the task\r\n\r\nht...         pomek
# 12452  The linter rule forbids committing changes whe...  mremiszewski
# 12453  Here I am trying to use the CK Editor in vue3,...         rg225
# 12454  Does anyone have a clue why the List styles ar...     timtempel
# 12455  ## Provide a description of the task\r\n\r\nIn...         pomek
#
#         Assignees                                           Comments  \
# 0      ['fredck']                                                 []
# 1              []  [{'body': 'This includes the introduction of t...
# 2              []  [{'body': 'Because of #19, nothing must be don...
# 3              []  [{'body': 'This is prototyped here:\nhttps://g...
# 4              []  [{'body': 'This has been prototyped here:\nhtt...
# ...           ...                                                ...
# 12451   ['pomek']                                                 []
# 12452          []  [{'body': 'For future reference, we figured ou...
# 12453          []                                                 []
# 12454          []  [{'body': 'Apologies, super stubborn browser c...
# 12455          []                                                 []
#
#                                                   Labels Issue State  \
# 0                                   ['type:improvement']      CLOSED
# 1                                   ['type:improvement']      CLOSED
# 2                                   ['type:improvement']      CLOSED
# 3                                   ['type:improvement']      CLOSED
# 4                                   ['type:improvement']      CLOSED
# ...                                                  ...         ...
# 12451  ['type:task', 'squad:devops', 'squad:core', 's...        OPEN
# 12452     ['type:bug', 'squad:devops', 'domain:linters']        OPEN
# 12453                                  ['type:question']        OPEN
# 12454                                  ['type:question']      CLOSED
# 12455       ['type:task', 'squad:devops', 'package:dev']        OPEN
#
#        Issue Number References
# 0               1.0         []
# 1               2.0         []
# 2               3.0         []
# 3               4.0         []
# 4               5.0         []
# ...             ...        ...
# 12451       15424.0         []
# 12452       15426.0         []
# 12453       15427.0   ['6296']
# 12454       15428.0         []
# 12455       15429.0         []
#
# [12456 rows x 9 columns]

# %%
#check how many Nan values are there
print("Amount of nan values:", df.isnull().sum())

#display Nan Issue Body values
df[df['Issue Body'].isnull()].head()
# Out:
# Amount of nan values: Issue Title       0
# Issue Body      127
# Author           32
# Assignees         0
# Comments          0
# Labels            0
# Issue State       0
# Issue Number      0
# References        0
# dtype: int64
#                                            Issue Title Issue Body     Author  \
# 5            package.json should be indented with tabs        NaN    Reinmar
# 47       [Windows] Builder builds tests as source code        NaN    Reinmar
# 235  Check automated and manual tests compatibility...        NaN  maxbarnas
# 318  Initial integration with Umberto. Prepare exam...        NaN    m-turek
# 330   Add a gulp task for generating JSDoc output only        NaN    m-turek
#
#          Assignees                                           Comments  \
# 5               []  [{'body': 'The current formatting is on purpos...
# 47              []                                                 []
# 235  ['maxbarnas']  [{'body': "What about manual tests? It's worth...
# 318    ['m-turek']                                                 []
# 330    ['m-turek']                                                 []
#
#                Labels Issue State  Issue Number References
# 5        ['type:bug']      CLOSED           7.0         []
# 47                 []      CLOSED          64.0         []
# 235     ['type:task']      CLOSED         329.0    ['156']
# 318     ['type:task']      CLOSED         427.0         []
# 330  ['type:feature']      CLOSED         442.0         []

# %%
#display Nan Author values
df[df['Author'].isnull()].head()
# Out:
#                                            Issue Title  \
# 99              Feature request: Toolbar customization
# 101                           Question: CKE5 and React
# 328  Switch headings using dropdown causing unexpec...
# 494                 Mobile examples not working for me
# 843               Detect changes in the editor content
#
#                                             Issue Body Author Assignees  \
# 99   Would be nice to provide a way to let users/de...    NaN        []
# 101  Will the CKE5 release good to work with ReactJ...    NaN        []
# 328  I am using windows 10 with chrome 58.0.3029.11...    NaN        []
# 494  Hi,\r\n\r\nCongrats on the big achievement wit...    NaN        []
# 843  ## Is this a bug report or feature request? (c...    NaN        []
#
#                                               Comments  \
# 99   [{'body': "Hey, thanks for the ideas!\n\nWe're...
# 101  [{'body': "That's an interesting question, @Ze...
# 328  [{'body': "Thanks for the ticket! We're aware ...
# 494  [{'body': "Please see here for information abo...
# 843  [{'body': 'CKEditor 5 provides an event which ...
#
#                                                 Labels Issue State  \
# 99                            ['resolution:duplicate']      CLOSED
# 101  ['resolution:duplicate', 'type:question', 'sta...      CLOSED
# 328                           ['resolution:duplicate']      CLOSED
# 494                             ['resolution:invalid']      CLOSED
# 843                                  ['type:question']      CLOSED
#
#      Issue Number      References
# 99          136.0         ['143']
# 101         138.0              []
# 328         440.0         ['228']
# 494         621.0  ['542', '603']
# 843         996.0              []

# %%
#check how many duplicate issues are there
print("\nAmount of duplicate issues:", df.duplicated().sum())
# Out:
# Amount of duplicate issues: 0

# %%
#filter out the issues with label epic in it
epic_df = df[df['Labels'].str.contains('Epic', na=False)]
df = df[~df['Labels'].str.contains('Epic', na=False)]

epic_df
# Out:
#                                              Issue Title  \
# 298    Introduce a way to reach unaccessible places (...
# 568                                 Allow linking images
# 876                                Implement list styles
# 877    Implement ordered lists start index and revers...
# 1227                            Find and replace feature
# ...                                                  ...
# 11943                       Document list feature parity
# 12209                                     List v1 sunset
# 12262  Further enhancements to the drag & drop: list ...
# 12280  Better entry point for image file managers and...
# 12435                        Create a custom "stale" bot
#
#                                               Issue Body          Author  \
# 298    Problem:\r\n\r\n![image](https://user-images.g...         Reinmar
# 568    ## 🐞 Is this a bug report or feature request? ...  davidpolberger
# 876    The user should be able to choose the style of...         Reinmar
# 877    Beside [list styles](https://github.com/ckedit...         Reinmar
# 1227   🆕 Feature request\r\n\r\n## CKEditor 5\r\n\r\n...         addsimm
# ...                                                  ...             ...
# 11943  The goal of this initiative is to make `Docume...          Witoso
# 12209  After the:\r\n\r\n*    [ ]  https://github.com...          Witoso
# 12262  ## 📝 Provide a description of the improvement\...          Witoso
# 12280  ## 📝 Provide a description of the new feature\...          Witoso
# 12435  ## Provide a description of the task\r\n\r\nAs...           pomek
#
#        Assignees                                           Comments  \
# 298     ['oleq']  [{'body': 'DUP reported in https://github.com/...
# 568           []  [{'body': "I thought there was a ticket for it...
# 876    ['pomek']  [{'body': '@Reinmar \r\n\r\nWe also in an eed ...
# 877           []  [{'body': 'Microsoft word has this feature use...
# 1227          []  [{'body': "Hi @addsimm! There's no such featur...
# ...          ...                                                ...
# 11943         []                                                 []
# 12209         []                                                 []
# 12262         []                                                 []
# 12280         []  [{'body': 'The idea would be to push the confi...
# 12435         []  [{'body': 'Epic branch: https://github.com/cke...
#
#                                                   Labels Issue State  \
# 298    ['type:bug', 'type:improvement', 'type:feature...      CLOSED
# 568    ['type:feature', 'package:link', 'support:2', ...      CLOSED
# 876    ['type:feature', 'package:list', 'support:2', ...      CLOSED
# 877    ['type:feature', 'package:list', 'support:2', ...      CLOSED
# 1227   ['status:discussion', 'type:feature', 'support...      CLOSED
# ...                                                  ...         ...
# 11943                ['type:task', 'Epic', 'squad:core']      CLOSED
# 12209                             ['Epic', 'squad:core']        OPEN
# 12262         ['type:improvement', 'Epic', 'squad:core']        OPEN
# 12280  ['type:feature', 'package:image', 'Epic', 'squ...        OPEN
# 12435  ['type:task', 'Epic', 'squad:devops', 'package...        OPEN
#
#        Issue Number                                         References
# 298           407.0  ['1400', '407', '1703', '1621', '685', '1546',...
# 568           702.0                              ['7519', '649', '85']
# 876          1031.0  ['7736', '7801', '5752', '1028', '7803', '7804...
# 877          1032.0                                           ['1031']
# 1227         1430.0                                           ['1257']
# ...             ...                                                ...
# 11943       14632.0                                                 []
# 12209       15037.0                                          ['14632']
# 12262       15110.0  ['14766', '14712', '15058', '14735', '14711', ...
# 12280       15149.0                                                 []
# 12435       15399.0                                                 []
#
# [78 rows x 9 columns]

# %%
#lets examine issue bodies of epic issues
epic_df['Issue Body'].iloc[5]
# Out:
# "## Is this a bug report or feature request? (choose one)\n\n🆕 Feature request\n\n## 💻 Version of CKEditor\n\nCKEditor version 5, decoupled document build\n\n## 📋 Steps to reproduce\n\n1. insert one small image\n2. insert another small image\n\n## ✅ Expected result\nTwo small images should be in same line with space e.g. Image1   Image2\n\n## ❎ Actual result\n\nCurrently they are stacked up from top to bottom.\n\n---\n\n## Future work\nMVP step 2: https://github.com/ckeditor/ckeditor5/issues/8666\nNice to have features: https://github.com/ckeditor/ckeditor5/issues/8712\n\n---\n\nIf you'd like to see this feature implemented, add 👍 to this post."

# %%
df[df["Issue Number"] == 8666]
# Out:
#                      Issue Title  \
# 7860  Inline images - MVP step 2
#
#                                              Issue Body    Author Assignees  \
# 7860  - [ ] Linking images (we're fine with this: `<...  pkwasnik        []
#
#                                                Comments  \
# 7860  [{'body': 'Remember about link decorators.', '...
#
#                                                  Labels Issue State  \
# 7860  ['type:feature', 'package:image', 'domain:ui/u...      CLOSED
#
#       Issue Number References
# 7860        8666.0         []

# %%
df
# Out:
#                                              Issue Title  \
# 0                          Introduce tests and Bender.js
# 1                                  Introduce the AMD API
# 2                              Introduce CKEDITOR.create
# 3                                Plugins path resolution
# 4                            Introduce the build process
# ...                                                  ...
# 12451          Make the `UpcastEvent` definition visible
# 12452  Linter error when changing `augmentation.ts` f...
# 12453  CKEditor In Vue3 - CKEditorError: ckeditor-dup...
# 12454               ListProperties not showin in Toolbar
# 12455       Changelog generator - ability to format date
#
#                                               Issue Body        Author  \
# 0      The infrastructure for testing must be created...        fredck
# 1      The AMD API must be introduced according to [i...        fredck
# 2      Introduce the `CKEDITOR.create` method and the...        fredck
# 3      The RequireJS "plugin" plugin must be created ...        fredck
# 4                The build process must be introduced.\n        fredck
# ...                                                  ...           ...
# 12451  ## Provide a description of the task\r\n\r\nht...         pomek
# 12452  The linter rule forbids committing changes whe...  mremiszewski
# 12453  Here I am trying to use the CK Editor in vue3,...         rg225
# 12454  Does anyone have a clue why the List styles ar...     timtempel
# 12455  ## Provide a description of the task\r\n\r\nIn...         pomek
#
#         Assignees                                           Comments  \
# 0      ['fredck']                                                 []
# 1              []  [{'body': 'This includes the introduction of t...
# 2              []  [{'body': 'Because of #19, nothing must be don...
# 3              []  [{'body': 'This is prototyped here:\nhttps://g...
# 4              []  [{'body': 'This has been prototyped here:\nhtt...
# ...           ...                                                ...
# 12451   ['pomek']                                                 []
# 12452          []  [{'body': 'For future reference, we figured ou...
# 12453          []                                                 []
# 12454          []  [{'body': 'Apologies, super stubborn browser c...
# 12455          []                                                 []
#
#                                                   Labels Issue State  \
# 0                                   ['type:improvement']      CLOSED
# 1                                   ['type:improvement']      CLOSED
# 2                                   ['type:improvement']      CLOSED
# 3                                   ['type:improvement']      CLOSED
# 4                                   ['type:improvement']      CLOSED
# ...                                                  ...         ...
# 12451  ['type:task', 'squad:devops', 'squad:core', 's...        OPEN
# 12452     ['type:bug', 'squad:devops', 'domain:linters']        OPEN
# 12453                                  ['type:question']        OPEN
# 12454                                  ['type:question']      CLOSED
# 12455       ['type:task', 'squad:devops', 'package:dev']        OPEN
#
#        Issue Number References
# 0               1.0         []
# 1               2.0         []
# 2               3.0         []
# 3               4.0         []
# 4               5.0         []
# ...             ...        ...
# 12451       15424.0         []
# 12452       15426.0         []
# 12453       15427.0   ['6296']
# 12454       15428.0         []
# 12455       15429.0         []
#
# [12378 rows x 9 columns]
