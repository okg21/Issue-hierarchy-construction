# %%
import pandas as pd
from transformers import BertTokenizer, BertModel
from sklearn.cluster import KMeans
import torch
import numpy as np
import matplotlib.pyplot as plt
import re
import json
import tqdm
# Out:
# 2023-12-11 14:44:36.720413: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-11 14:44:37.291220: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 14:44:38.365121: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-12-11 14:44:38.365266: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-12-11 14:44:38.365274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# Read the data
csv_path = 'ckeditor5_issues.csv'
df = pd.read_csv(csv_path)
owner, name = df['Repo Owner'][0], df['Repo Name'][0]

# %%
def extract_issue_ref(text):
    """Takes text as the input
    Returns the issue references mentioned in the input text"""
    if not isinstance(text, str):
        # If text is not a string, make it a string
        text = str(text)

    issue_url_regex = r'/' + owner + r'/' + name + r'/issues/(\d+)'
    matches = re.findall(issue_url_regex, text)
    issue_numbers_http = set([match for match in matches])

    edge_regex =  r'' + owner + r'/' + name + r'#(\d+)'
    matches = re.findall(edge_regex, text)
    issue_numbers_edge = set([match for match in matches])

    task_regex =  r'\[([xX]|\s)\]\s?#(\d+)' #6330
    matches = re.findall(task_regex, text)
    issue_numbers_hashtag = set([match[1] for match in matches])


    return set(list(issue_numbers_edge) + list(issue_numbers_http) + list(issue_numbers_hashtag))

# %%
# Extract issue references from the issue bodies
df['References'] = df.apply(lambda row: (list(set(extract_issue_ref(row['Issue Body'])))), axis=1)

# %%
# Construct the epic_df which contains issues with epic labels
epic_df = df[df['Labels'].str.contains('Epic', na=False)]
#df = df[~df['Labels'].str.contains('Epic', na=False)]

# %%
# Construct ref_set which contains all the references of the whole repository
ref_set = set()
for ref in epic_df['References']:
    ref_set = ref + list(ref_set)

# %%
# Remove issue that are not referenced from anywhere
df = df[df['Issue Number'].astype(int).astype(str).isin(ref_set)]

# %%
# Drop NaN values
df = df.dropna(subset=['Issue Title', 'Issue Body'])
#df.reindex()

# %%
# Combine issue title and body for getting the combined text
df['Combined Text'] = df['Issue Title'] + ' ' + df['Issue Body']

# %%
# Use BERT for getting embeddings for issues
# Load pre-trained BERT model and tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

batch_size = 128
mean_embeddings_np = np.empty((0, 768))
# Process the data in batches
for i in range(0, len(df), batch_size):
    batch_df = df.iloc[i:i+batch_size]

    # Concatenate 'Issue Body' and 'Issue Title'
    batch_df['Combined Text'] = batch_df['Issue Title'] + ' ' + batch_df['Issue Body']

    # Tokenize and encode the texts
    tokens = tokenizer(batch_df['Combined Text'].tolist(), return_tensors='pt', padding=True, truncation=True, max_length=512)

    # Forward pass, get hidden states
    with torch.no_grad():
        outputs = model(**tokens)

    # Take the output embeddings from the last layer
    last_hidden_states = outputs.last_hidden_state

    # Pooling strategy: Take the mean of all token embeddings
    mean_embeddings = torch.mean(last_hidden_states, dim=1)

    # Convert the tensor to a numpy array
    mean_embeddings_np = np.append(mean_embeddings_np, mean_embeddings.numpy(), axis=0)
    #mean_embeddings_np = mean_embeddings.numpy()
# Out:
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# /tmp/ipykernel_12886/496396809.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch_df['Combined Text'] = batch_df['Issue Title'] + ' ' + batch_df['Issue Body']

# %%
# Epics with references
epic_df = epic_df[epic_df['References'].apply(lambda x: len(x) > 0)]
epic_df = epic_df.reset_index(drop=True)
epic_df
# Out:
#    Repo Owner  Repo Name                                        Issue Title  \
# 0    ckeditor  ckeditor5  Introduce a way to reach unaccessible places (...
# 1    ckeditor  ckeditor5                              Implement list styles
# 2    ckeditor  ckeditor5  Implement ordered lists start index and revers...
# 3    ckeditor  ckeditor5  Inline images - support multiple images in a s...
# 4    ckeditor  ckeditor5          Table cell/row/column selection – stage I
# 5    ckeditor  ckeditor5                           Implement table captions
# 6    ckeditor  ckeditor5                                 Restricted editing
# 7    ckeditor  ckeditor5  Replacement of the CKEditor 4's styles dropdow...
# 8    ckeditor  ckeditor5         Table cell/row/column selection – stage II
# 9    ckeditor  ckeditor5  Table cell/row/column selection – stage III (o...
# 10   ckeditor  ckeditor5                              Migration to monorepo
# 11   ckeditor  ckeditor5  Conversion: Re-converting the entire "thing" w...
# 12   ckeditor  ckeditor5                        Monorepo migration stage II
# 13   ckeditor  ckeditor5                             Migrate to beforeInput
# 14   ckeditor  ckeditor5       Drag and drop of textual content and widgets
# 15   ckeditor  ckeditor5                     Project migration to webpack 5
# 16   ckeditor  ckeditor5                  Find and replace 29.0.0 followups
# 17   ckeditor  ckeditor5     Redesign and introduce new reconversion system
# 18   ckeditor  ckeditor5  Resolve integration issues between commands an...
# 19   ckeditor  ckeditor5                       Migrate to beforeInput vol 2
# 20   ckeditor  ckeditor5                     [Style dropdown] Stabilization
# 21   ckeditor  ckeditor5                   Migrate CKEditor 5 to TypeScript
# 22   ckeditor  ckeditor5      Migrate CKEditor 5 to TypeScript - follow-ups
# 23   ckeditor  ckeditor5  [beforeInput] Bring back basic typing support ...
# 24   ckeditor  ckeditor5  Improve editor initialization time (scenarios ...
# 25   ckeditor  ckeditor5                            Drag and Drop of blocks
# 26   ckeditor  ckeditor5  Support adjacent lists (splitting, resetting n...
# 27   ckeditor  ckeditor5              🖼️  Supporting image height attribute
# 28   ckeditor  ckeditor5                      [Style dropdown] Improvements
# 29   ckeditor  ckeditor5                       Document list feature parity
# 30   ckeditor  ckeditor5                                     List v1 sunset
# 31   ckeditor  ckeditor5  Further enhancements to the drag & drop: list ...
# 32   ckeditor  ckeditor5                        Create a custom "stale" bot
#
#                                            Issue Body       Author  \
# 0   Problem:\r\n\r\n![image](https://user-images.g...      Reinmar
# 1   The user should be able to choose the style of...      Reinmar
# 2   Beside [list styles](https://github.com/ckedit...      Reinmar
# 3   ## Is this a bug report or feature request? (c...  ateeqsuhail
# 4   We started to work on the table selection feat...      Reinmar
# 5   Tables need to be captioned. Most likely, we c...      Reinmar
# 6   ## 📝 Provide a description of the new feature\...      Reinmar
# 7   ## What? (tl;dr)\r\n\r\nCKEditor 4 offered a [...      Reinmar
# 8   This is a followup for the table selection MVP...      jodator
# 9   This is a followup for the table selection opt...      jodator
# 10  We've been using multirepo for quite some time...      Reinmar
# 11  ## Background\r\n\r\nHow does conversion work ...      Reinmar
# 12  ## Provide a description of the task\r\n\r\nIn...      mlewand
# 13  ## 📝 Provide a description of the improvement\...      Reinmar
# 14  ## 📝 Provide a description of the new feature\...    niegowski
# 15  The list below contains (I hope) all tasks req...        pomek
# 16  ## Provide a description of the task\r\n\r\nTh...      mlewand
# 17  ## EDIT (Summary of changes)\r\n\r\nYou can fi...    niegowski
# 18  This epic started with a _"Export to PDF/Word ...      Reinmar
# 19  ## 📝 Provide a description of the new feature\...         oleq
# 20  This issue aggregates bugs and improvements to...         oleq
# 21  Back in 2015 when we were bootstrapping CKEdit...      Reinmar
# 22  This issue serves as an umbrella for all the t...      arkflpc
# 23  In a course of action in https://github.com/ck...      Reinmar
# 24  ## 📝 Provide a description of the improvement\...         Mgsy
# 25  Currently, CKEditor 5 allows dragging textual ...       Witoso
# 26  ## Use cases\r\nAs a user, I want to insert co...       Witoso
# 27  # Image feature compatibility with CKEditor 4 ...       Witoso
# 28  Improvements to our [Styles plugin](https://ck...       Witoso
# 29  The goal of this initiative is to make `Docume...       Witoso
# 30  After the:\r\n\r\n*    [ ]  https://github.com...       Witoso
# 31  ## 📝 Provide a description of the improvement\...       Witoso
# 32  ## Provide a description of the task\r\n\r\nAs...        pomek
#
#                 Assignees                                           Comments  \
# 0                ['oleq']  [{'body': 'DUP reported in https://github.com/...
# 1               ['pomek']  [{'body': '@Reinmar \r\n\r\nWe also in an eed ...
# 2                      []  [{'body': 'Microsoft word has this feature use...
# 3                      []  [{'body': 'any work around/alternative for the...
# 4                      []  [{'body': 'Some POC of fake selection in table...
# 5           ['maxbarnas']  [{'body': 'I hope this is the right issue to p...
# 6     ['jodator', 'oleq']  [{'body': '## Icon\r\n\r\nTwo proposals here, ...
# 7                      []  [{'body': "One thing to consider: People use o...
# 8                      []  [{'body': 'Hi, is the cell/row/column selectio...
# 9                      []                                                 []
# 10                     []  [{'body': 'Added the [`monorepo-mock`](https:/...
# 11                     []  [{'body': "Another doubt that came to my mind:...
# 12                     []                                                 []
# 13               ['oleq']  [{'body': "Order of things:\n1. In the beginni...
# 14          ['niegowski']  [{'body': '![](https://user-images.githubuserc...
# 15              ['pomek']  [{'body': "Regarding the documentation:\r\n\r\...
# 16                     []  [{'body': 'I did iterative merge to `master` w...
# 17          ['niegowski']  [{'body': 'The `elementToStructure` PoC is now...
# 18                     []  [{'body': 'List of issues closed in this Epic:...
# 19  ['oleq', 'niegowski']  [{'body': '@oleq Will this also address #2045?...
# 20                     []  [{'body': 'Should [#13341](https://github.com/...
# 21                     []  [{'body': "> *   Once again I'd like to thank ...
# 22                     []  [{'body': '## Replace "export type" by "export...
# 23          ['niegowski']  [{'body': "Let's try to approach this in 3 sta...
# 24                     []  [{'body': 'The improvement should be for inlin...
# 25                     []  [{'body': 'Further enhancements extracted to t...
# 26                     []  [{'body': 'Example #1\r\n```html\r\n<p>\r\n  L...
# 27       ['mmotyczynska']  [{'body': 'Questions:\n* non intuitive when se...
# 28                     []  [{'body': "Drupal uses the official `Image` pl...
# 29                     []                                                 []
# 30                     []                                                 []
# 31                     []                                                 []
# 32                     []  [{'body': 'Epic branch: https://github.com/cke...
#
#                                                Labels Issue State  \
# 0   ['type:bug', 'type:improvement', 'type:feature...      CLOSED
# 1   ['type:feature', 'package:list', 'support:2', ...      CLOSED
# 2   ['type:feature', 'package:list', 'support:2', ...      CLOSED
# 3   ['type:feature', 'package:image', 'support:2',...      CLOSED
# 4           ['type:feature', 'package:table', 'Epic']      CLOSED
# 5   ['type:feature', 'package:table', 'support:2',...      CLOSED
# 6   ['type:feature', 'package:restricted-editing',...      CLOSED
# 7   ['type:feature', 'support:2', 'Epic', 'squad:c...      CLOSED
# 8                           ['package:table', 'Epic']      CLOSED
# 9           ['type:feature', 'package:table', 'Epic']      CLOSED
# 10                       ['type:improvement', 'Epic']      CLOSED
# 11  ['resolution:duplicate', 'type:improvement', '...      CLOSED
# 12              ['type:task', 'Epic', 'squad:devops']      CLOSED
# 13  ['resolution:duplicate', 'type:improvement', '...      CLOSED
# 14  ['type:feature', 'package:clipboard', 'domain:...      CLOSED
# 15  ['type:task', 'Epic', 'bc:major', 'squad:devops']      CLOSED
# 16  ['type:improvement', 'type:task', 'Epic', 'squ...      CLOSED
# 17  ['type:feature', 'package:engine', 'support:2'...      CLOSED
# 18         ['type:improvement', 'Epic', 'squad:core']      CLOSED
# 19  ['type:feature', 'package:engine', 'package:ty...      CLOSED
# 20  ['Epic', 'squad:core', 'resolution:resolved', ...      CLOSED
# 21  ['type:task', 'Epic', 'domain:dx', 'squad:core...      CLOSED
# 22                ['Epic', 'squad:core', 'domain:ts']        OPEN
# 23  ['type:task', 'domain:typing/ime', 'Epic', 'sq...      CLOSED
# 24  ['type:improvement', 'package:ui', 'support:2'...      CLOSED
# 25             ['domain:ui/ux', 'Epic', 'squad:core']      CLOSED
# 26  ['type:improvement', 'package:list', 'Epic', '...      CLOSED
# 27  ['package:image', 'domain:ui/ux', 'Epic', 'squ...      CLOSED
# 28            ['Epic', 'squad:core', 'package:style']        OPEN
# 29                ['type:task', 'Epic', 'squad:core']      CLOSED
# 30                             ['Epic', 'squad:core']        OPEN
# 31         ['type:improvement', 'Epic', 'squad:core']        OPEN
# 32  ['type:task', 'Epic', 'squad:devops', 'package...        OPEN
#
#     Issue Number                                         References
# 0          407.0                                              [331]
# 1         1031.0                                             [1028]
# 2         1032.0                                             [1031]
# 3         2052.0                                       [8666, 8712]
# 4         3202.0  [6347, 6151, 6353, 6128, 6346, 6343, 6284, 611...
# 5         3204.0                                              [610]
# 6         5683.0                                       [5804, 5802]
# 7         5700.0                                        [648, 3416]
# 8         6285.0   [6357, 3267, 6521, 6500, 6401, 6123, 6406, 6382]
# 9         6297.0   [6122, 6453, 6446, 6120, 6121, 6115, 6769, 6631]
# 10        6466.0                     [6477, 6476, 6478, 6480, 6534]
# 11        6510.0                                       [1589, 6506]
# 12        6746.0                                             [6479]
# 13        7462.0  [7999, 8008, 8009, 8001, 8012, 8013, 7997, 799...
# 14        9128.0                                             [2664]
# 15        9799.0                                             [6770]
# 16       10024.0                 [10146, 10001, 9934, 10040, 10014]
# 17       10294.0                                            [11268]
# 18       10676.0                                            [10493]
# 19       11438.0                                            [11904]
# 20       11574.0  [11581, 11588, 11590, 11578, 11580, 11607, 115...
# 21       11704.0                                        [504, 1415]
# 22       12027.0  [11723, 11888, 13434, 12763, 13855, 12853, 138...
# 23       12058.0                                     [12058, 11438]
# 24       12592.0                                     [12890, 12682]
# 25       13933.0  [14640, 14831, 14709, 14734, 14645, 14646, 150...
# 26       13945.0                                            [12738]
# 27       14146.0  [14357, 14532, 14557, 14202, 14366, 14531, 515...
# 28       14274.0  [14372, 11577, 13341, 12777, 12625, 14216, 137...
# 29       14632.0                       [12466, 14663, 11620, 14634]
# 30       15037.0                                     [14942, 14632]
# 31       15110.0  [14711, 14739, 14641, 14643, 14712, 14940, 147...
# 32       15399.0                       [15403, 15402, 15400, 15401]

# %%
# Delete no longer used variables
del mean_embeddings
del tokenizer
del model
del last_hidden_states
del outputs
del tokens

# %%
# Elbow Method to determine the optimal number of clusters
distortions = []
max_clusters = 20  # You can adjust this based on your expectations
for i in range(1, max_clusters + 1):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(mean_embeddings_np)
    distortions.append(kmeans.inertia_)

# Plot the elbow graph
plt.plot(range(1, max_clusters + 1), distortions, marker='o')
plt.title('Elbow Method for Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()
# Out:
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Choose the optimal number of clusters based on the plot
optimal_num_clusters = 32#int(input("Enter the optimal number of clusters based on the elbow method: "))

# Perform clustering with the chosen number of clusters
kmeans = KMeans(n_clusters=optimal_num_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(mean_embeddings_np)

# Add cluster labels to the DataFrame
df['Cluster'] = cluster_labels
df = df.reset_index(drop=True)
df['Issue Number'] = df['Issue Number'].astype(int)

# Display the DataFrame with cluster labels
df
# Out:
# /home/okg21/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#     Repo Owner  Repo Name                                        Issue Title  \
# 0     ckeditor  ckeditor5  There should be an empty paragraph in the newl...
# 1     ckeditor  ckeditor5                             Typings for TypeScript
# 2     ckeditor  ckeditor5                                      Table feature
# 3     ckeditor  ckeditor5                                      Style feature
# 4     ckeditor  ckeditor5  Feature Request: Cycle Through List Styles on ...
# ..         ...        ...                                                ...
# 173   ckeditor  ckeditor5         Drag by balloon block toolbar improvements
# 174   ckeditor  ckeditor5  Find issues matching criteria to mark them as ...
# 175   ckeditor  ckeditor5  Determine if stale issues need an action (clos...
# 176   ckeditor  ckeditor5      Create an executable script for the stale bot
# 177   ckeditor  ckeditor5    Replace the existing stale bot with the new one
#
#                                             Issue Body      Author  \
# 0    When you create an editor, but not call `setDa...     pjasiun
# 1    Hi,\r\n\r\nI'm currently using ckeditor5 in Ty...    ssougnez
# 2    We plan to bootstrap the table feature very so...     Reinmar
# 3    I would like to propose the **Styles** feature...      fredck
# 4    Rather than supporting "ordered list" and "ord...  duracell80
# ..                                                 ...         ...
# 173  As we implemented the new drag behavior by bal...      Witoso
# 174  ## Provide a description of the task\r\n\r\nTh...       pomek
# 175  ## Provide a description of the task\n\nThe go...       pomek
# 176  ## Provide a description of the task\n\nThe go...       pomek
# 177  ## Provide a description of the task\n\nReplac...       pomek
#
#        Assignees                                           Comments  \
# 0             []  [{'body': 'As a matter of fact, that paragraph...
# 1             []  [{'body': "Quoting myself from https://github....
# 2    ['jodator']  [{'body': 'One of the first things we have to ...
# 3             []  [{'body': 'As much as I understand the idea, I...
# 4             []  [{'body': '> This isn\'t something a designer ...
# ..           ...                                                ...
# 173           []                                                 []
# 174  ['psmyrek']  [{'body': '@psmyrek, could we add a dry mode t...
# 175  ['psmyrek']                                                 []
# 176  ['psmyrek']                                                 []
# 177  ['psmyrek']                                                 []
#
#                                                 Labels Issue State  \
# 0         ['resolution:duplicate', 'type:improvement']      CLOSED
# 1          ['type:feature', 'support:2', 'squad:core']      CLOSED
# 2             ['type:feature', 'domain:accessibility']      CLOSED
# 3    ['status:discussion', 'type:feature', 'support...        OPEN
# 4                             ['resolution:duplicate']      CLOSED
# ..                                                 ...         ...
# 173  ['type:improvement', 'package:clipboard', 'squ...        OPEN
# 174  ['type:task', 'squad:devops', 'package:dev', '...        OPEN
# 175  ['type:task', 'squad:devops', 'package:dev', '...        OPEN
# 176       ['type:task', 'squad:devops', 'package:dev']        OPEN
# 177       ['type:task', 'squad:devops', 'package:dev']        OPEN
#
#      Issue Number    References  \
# 0             331            []
# 1             504  [504, 11704]
# 2             610            []
# 3             648            []
# 4            1028            []
# ..            ...           ...
# 173         15058            []
# 174         15400       [15399]
# 175         15401       [15399]
# 176         15402       [15399]
# 177         15403       [15399]
#
#                                          Combined Text  Cluster  \
# 0    There should be an empty paragraph in the newl...        6
# 1    Typings for TypeScript Hi,\r\n\r\nI'm currentl...        1
# 2    Table feature We plan to bootstrap the table f...       23
# 3    Style feature I would like to propose the **St...       16
# 4    Feature Request: Cycle Through List Styles on ...        1
# ..                                                 ...      ...
# 173  Drag by balloon block toolbar improvements As ...       22
# 174  Find issues matching criteria to mark them as ...       18
# 175  Determine if stale issues need an action (clos...       18
# 176  Create an executable script for the stale bot ...        7
# 177  Replace the existing stale bot with the new on...       22
#
#      GroundTruthCluster
# 0                     0
# 1                    21
# 2                     5
# 3                     7
# 4                     1
# ..                  ...
# 173                  31
# 174                  32
# 175                  32
# 176                  32
# 177                  32
#
# [178 rows x 14 columns]

# %%
# Construct ground truth
gt = [0] * df.shape[0]
df['GroundTruthCluster'] = [0] * df.shape[0]
for i in range(epic_df.shape[0]):
    for j in epic_df.iloc[i]['References']:
        print(df[df['Issue Number'] == int(j)].index)
        print(j)
        gt[(df[df['Issue Number'] == int(j)].index).astype(int)[0]] = i

df['GroundTruthCluster'] = gt
# Out:
# Int64Index([0], dtype='int64')
# 331
# Int64Index([4], dtype='int64')
# 1028
# Int64Index([5], dtype='int64')
# 1031
# Int64Index([73], dtype='int64')
# 8666
# Int64Index([74], dtype='int64')
# 8712
# Int64Index([39], dtype='int64')
# 6347
# Int64Index([29], dtype='int64')
# 6151
# Int64Index([41], dtype='int64')
# 6353
# Int64Index([27], dtype='int64')
# 6128
# Int64Index([38], dtype='int64')
# 6346
# Int64Index([37], dtype='int64')
# 6343
# Int64Index([31], dtype='int64')
# 6284
# Int64Index([17], dtype='int64')
# 6116
# Int64Index([14], dtype='int64')
# 6113
# Int64Index([25], dtype='int64')
# 6126
# Int64Index([34], dtype='int64')
# 6301
# Int64Index([35], dtype='int64')
# 6328
# Int64Index([15], dtype='int64')
# 6114
# Int64Index([24], dtype='int64')
# 6125
# Int64Index([18], dtype='int64')
# 6118
# Int64Index([33], dtype='int64')
# 6297
# Int64Index([19], dtype='int64')
# 6119
# Int64Index([26], dtype='int64')
# 6127
# Int64Index([30], dtype='int64')
# 6154
# Int64Index([36], dtype='int64')
# 6330
# Int64Index([28], dtype='int64')
# 6150
# Int64Index([40], dtype='int64')
# 6348
# Int64Index([32], dtype='int64')
# 6285
# Int64Index([2], dtype='int64')
# 610
# Int64Index([13], dtype='int64')
# 5804
# Int64Index([12], dtype='int64')
# 5802
# Int64Index([3], dtype='int64')
# 648
# Int64Index([10], dtype='int64')
# 3416
# Int64Index([42], dtype='int64')
# 6357
# Int64Index([9], dtype='int64')
# 3267
# Int64Index([55], dtype='int64')
# 6521
# Int64Index([53], dtype='int64')
# 6500
# Int64Index([44], dtype='int64')
# 6401
# Int64Index([23], dtype='int64')
# 6123
# Int64Index([45], dtype='int64')
# 6406
# Int64Index([43], dtype='int64')
# 6382
# Int64Index([22], dtype='int64')
# 6122
# Int64Index([47], dtype='int64')
# 6453
# Int64Index([46], dtype='int64')
# 6446
# Int64Index([20], dtype='int64')
# 6120
# Int64Index([21], dtype='int64')
# 6121
# Int64Index([16], dtype='int64')
# 6115
# Int64Index([58], dtype='int64')
# 6769
# Int64Index([57], dtype='int64')
# 6631
# Int64Index([49], dtype='int64')
# 6477
# Int64Index([48], dtype='int64')
# 6476
# Int64Index([50], dtype='int64')
# 6478
# Int64Index([52], dtype='int64')
# 6480
# Int64Index([56], dtype='int64')
# 6534
# Int64Index([7], dtype='int64')
# 1589
# Int64Index([54], dtype='int64')
# 6506
# Int64Index([51], dtype='int64')
# 6479
# Int64Index([64], dtype='int64')
# 7999
# Int64Index([67], dtype='int64')
# 8008
# Int64Index([68], dtype='int64')
# 8009
# Int64Index([66], dtype='int64')
# 8001
# Int64Index([71], dtype='int64')
# 8012
# Int64Index([72], dtype='int64')
# 8013
# Int64Index([62], dtype='int64')
# 7997
# Int64Index([61], dtype='int64')
# 7996
# Int64Index([69], dtype='int64')
# 8010
# Int64Index([70], dtype='int64')
# 8011
# Int64Index([65], dtype='int64')
# 8000
# Int64Index([60], dtype='int64')
# 7995
# Int64Index([63], dtype='int64')
# 7998
# Int64Index([8], dtype='int64')
# 2664
# Int64Index([59], dtype='int64')
# 6770
# Int64Index([79], dtype='int64')
# 10146
# Int64Index([76], dtype='int64')
# 10001
# Int64Index([75], dtype='int64')
# 9934
# Int64Index([78], dtype='int64')
# 10040
# Int64Index([77], dtype='int64')
# 10014
# Int64Index([83], dtype='int64')
# 11268
# Int64Index([80], dtype='int64')
# 10493
# Int64Index([106], dtype='int64')
# 11904
# Int64Index([92], dtype='int64')
# 11581
# Int64Index([96], dtype='int64')
# 11588
# Int64Index([97], dtype='int64')
# 11590
# Int64Index([89], dtype='int64')
# 11578
# Int64Index([91], dtype='int64')
# 11580
# Int64Index([100], dtype='int64')
# 11607
# Int64Index([86], dtype='int64')
# 11575
# Int64Index([109], dtype='int64')
# 12441
# Int64Index([95], dtype='int64')
# 11585
# Int64Index([87], dtype='int64')
# 11576
# Int64Index([102], dtype='int64')
# 11709
# Int64Index([94], dtype='int64')
# 11584
# Int64Index([93], dtype='int64')
# 11582
# Int64Index([104], dtype='int64')
# 11748
# Int64Index([1], dtype='int64')
# 504
# Int64Index([6], dtype='int64')
# 1415
# Int64Index([103], dtype='int64')
# 11723
# Int64Index([105], dtype='int64')
# 11888
# Int64Index([123], dtype='int64')
# 13434
# Int64Index([115], dtype='int64')
# 12763
# Int64Index([129], dtype='int64')
# 13855
# Int64Index([119], dtype='int64')
# 12853
# Int64Index([127], dtype='int64')
# 13830
# Int64Index([113], dtype='int64')
# 12720
# Int64Index([125], dtype='int64')
# 13750
# Int64Index([108], dtype='int64')
# 12218
# Int64Index([124], dtype='int64')
# 13743
# Int64Index([128], dtype='int64')
# 13831
# Int64Index([107], dtype='int64')
# 12058
# Int64Index([85], dtype='int64')
# 11438
# Int64Index([120], dtype='int64')
# 12890
# Int64Index([112], dtype='int64')
# 12682
# Int64Index([146], dtype='int64')
# 14640
# Int64Index([165], dtype='int64')
# 14831
# Int64Index([153], dtype='int64')
# 14709
# Int64Index([157], dtype='int64')
# 14734
# Int64Index([149], dtype='int64')
# 14645
# Int64Index([150], dtype='int64')
# 14646
# Int64Index([172], dtype='int64')
# 15029
# Int64Index([121], dtype='int64')
# 12894
# Int64Index([82], dtype='int64')
# 11130
# Int64Index([162], dtype='int64')
# 14740
# Int64Index([163], dtype='int64')
# 14744
# Int64Index([171], dtype='int64')
# 14969
# Int64Index([154], dtype='int64')
# 14710
# Int64Index([170], dtype='int64')
# 14968
# Int64Index([130], dtype='int64')
# 14033
# Int64Index([8], dtype='int64')
# 2664
# Int64Index([114], dtype='int64')
# 12738
# Int64Index([137], dtype='int64')
# 14357
# Int64Index([141], dtype='int64')
# 14532
# Int64Index([143], dtype='int64')
# 14557
# Int64Index([134], dtype='int64')
# 14202
# Int64Index([138], dtype='int64')
# 14366
# Int64Index([140], dtype='int64')
# 14531
# Int64Index([11], dtype='int64')
# 5154
# Int64Index([132], dtype='int64')
# 14147
# Int64Index([136], dtype='int64')
# 14313
# Int64Index([81], dtype='int64')
# 10838
# Int64Index([133], dtype='int64')
# 14201
# Int64Index([84], dtype='int64')
# 11393
# Int64Index([142], dtype='int64')
# 14542
# Int64Index([131], dtype='int64')
# 14146
# Int64Index([139], dtype='int64')
# 14372
# Int64Index([88], dtype='int64')
# 11577
# Int64Index([122], dtype='int64')
# 13341
# Int64Index([118], dtype='int64')
# 12777
# Int64Index([111], dtype='int64')
# 12625
# Int64Index([135], dtype='int64')
# 14216
# Int64Index([126], dtype='int64')
# 13778
# Int64Index([117], dtype='int64')
# 12771
# Int64Index([116], dtype='int64')
# 12770
# Int64Index([99], dtype='int64')
# 11606
# Int64Index([168], dtype='int64')
# 14946
# Int64Index([98], dtype='int64')
# 11591
# Int64Index([90], dtype='int64')
# 11579
# Int64Index([110], dtype='int64')
# 12466
# Int64Index([152], dtype='int64')
# 14663
# Int64Index([101], dtype='int64')
# 11620
# Int64Index([145], dtype='int64')
# 14634
# Int64Index([167], dtype='int64')
# 14942
# Int64Index([144], dtype='int64')
# 14632
# Int64Index([155], dtype='int64')
# 14711
# Int64Index([161], dtype='int64')
# 14739
# Int64Index([147], dtype='int64')
# 14641
# Int64Index([148], dtype='int64')
# 14643
# Int64Index([156], dtype='int64')
# 14712
# Int64Index([166], dtype='int64')
# 14940
# Int64Index([159], dtype='int64')
# 14737
# Int64Index([164], dtype='int64')
# 14766
# Int64Index([169], dtype='int64')
# 14950
# Int64Index([173], dtype='int64')
# 15058
# Int64Index([158], dtype='int64')
# 14735
# Int64Index([151], dtype='int64')
# 14647
# Int64Index([160], dtype='int64')
# 14738
# Int64Index([177], dtype='int64')
# 15403
# Int64Index([176], dtype='int64')
# 15402
# Int64Index([174], dtype='int64')
# 15400
# Int64Index([175], dtype='int64')
# 15401

# %%
# Check df with cluster ground truth included
df
# Out:
#     Repo Owner  Repo Name                                        Issue Title  \
# 0     ckeditor  ckeditor5  There should be an empty paragraph in the newl...
# 1     ckeditor  ckeditor5                             Typings for TypeScript
# 2     ckeditor  ckeditor5                                      Table feature
# 3     ckeditor  ckeditor5                                      Style feature
# 4     ckeditor  ckeditor5  Feature Request: Cycle Through List Styles on ...
# ..         ...        ...                                                ...
# 173   ckeditor  ckeditor5         Drag by balloon block toolbar improvements
# 174   ckeditor  ckeditor5  Find issues matching criteria to mark them as ...
# 175   ckeditor  ckeditor5  Determine if stale issues need an action (clos...
# 176   ckeditor  ckeditor5      Create an executable script for the stale bot
# 177   ckeditor  ckeditor5    Replace the existing stale bot with the new one
#
#                                             Issue Body      Author  \
# 0    When you create an editor, but not call `setDa...     pjasiun
# 1    Hi,\r\n\r\nI'm currently using ckeditor5 in Ty...    ssougnez
# 2    We plan to bootstrap the table feature very so...     Reinmar
# 3    I would like to propose the **Styles** feature...      fredck
# 4    Rather than supporting "ordered list" and "ord...  duracell80
# ..                                                 ...         ...
# 173  As we implemented the new drag behavior by bal...      Witoso
# 174  ## Provide a description of the task\r\n\r\nTh...       pomek
# 175  ## Provide a description of the task\n\nThe go...       pomek
# 176  ## Provide a description of the task\n\nThe go...       pomek
# 177  ## Provide a description of the task\n\nReplac...       pomek
#
#        Assignees                                           Comments  \
# 0             []  [{'body': 'As a matter of fact, that paragraph...
# 1             []  [{'body': "Quoting myself from https://github....
# 2    ['jodator']  [{'body': 'One of the first things we have to ...
# 3             []  [{'body': 'As much as I understand the idea, I...
# 4             []  [{'body': '> This isn\'t something a designer ...
# ..           ...                                                ...
# 173           []                                                 []
# 174  ['psmyrek']  [{'body': '@psmyrek, could we add a dry mode t...
# 175  ['psmyrek']                                                 []
# 176  ['psmyrek']                                                 []
# 177  ['psmyrek']                                                 []
#
#                                                 Labels Issue State  \
# 0         ['resolution:duplicate', 'type:improvement']      CLOSED
# 1          ['type:feature', 'support:2', 'squad:core']      CLOSED
# 2             ['type:feature', 'domain:accessibility']      CLOSED
# 3    ['status:discussion', 'type:feature', 'support...        OPEN
# 4                             ['resolution:duplicate']      CLOSED
# ..                                                 ...         ...
# 173  ['type:improvement', 'package:clipboard', 'squ...        OPEN
# 174  ['type:task', 'squad:devops', 'package:dev', '...        OPEN
# 175  ['type:task', 'squad:devops', 'package:dev', '...        OPEN
# 176       ['type:task', 'squad:devops', 'package:dev']        OPEN
# 177       ['type:task', 'squad:devops', 'package:dev']        OPEN
#
#      Issue Number    References  \
# 0             331            []
# 1             504  [504, 11704]
# 2             610            []
# 3             648            []
# 4            1028            []
# ..            ...           ...
# 173         15058            []
# 174         15400       [15399]
# 175         15401       [15399]
# 176         15402       [15399]
# 177         15403       [15399]
#
#                                          Combined Text  Cluster  \
# 0    There should be an empty paragraph in the newl...        6
# 1    Typings for TypeScript Hi,\r\n\r\nI'm currentl...        1
# 2    Table feature We plan to bootstrap the table f...       23
# 3    Style feature I would like to propose the **St...       16
# 4    Feature Request: Cycle Through List Styles on ...        1
# ..                                                 ...      ...
# 173  Drag by balloon block toolbar improvements As ...       22
# 174  Find issues matching criteria to mark them as ...       18
# 175  Determine if stale issues need an action (clos...       18
# 176  Create an executable script for the stale bot ...        7
# 177  Replace the existing stale bot with the new on...       22
#
#      GroundTruthCluster
# 0                     0
# 1                    21
# 2                     5
# 3                     7
# 4                     1
# ..                  ...
# 173                  31
# 174                  32
# 175                  32
# 176                  32
# 177                  32
#
# [178 rows x 14 columns]

# %%
# Calculate TP, TN, FP, FN
TP=0
TN=0
FP=0
FN=0
for i in range(df.shape[0]-1):
    for j in range(i+1, df.shape[0]):
        if df.iloc[i]['Cluster'] == df.iloc[j]['Cluster'] and df.iloc[i]['GroundTruthCluster'] == df.iloc[j]['GroundTruthCluster']:
            TP += 1
        elif df.iloc[i]['Cluster'] != df.iloc[j]['Cluster'] and df.iloc[i]['GroundTruthCluster'] != df.iloc[j]['GroundTruthCluster']:
            TN += 1
        elif df.iloc[i]['Cluster'] == df.iloc[j]['Cluster'] and df.iloc[i]['GroundTruthCluster'] != df.iloc[j]['GroundTruthCluster']:
            FP += 1
        elif df.iloc[i]['Cluster'] != df.iloc[j]['Cluster'] and df.iloc[i]['GroundTruthCluster'] == df.iloc[j]['GroundTruthCluster']:
            FN += 1
        else:
            print('Error: Unexpected case')

# %%
print('TP: ', TP)
print('TN: ', TN)
print('FP: ', FP)
print('FN: ', FN)
# Out:
# TP:  122
# TN:  14229
# FP:  573
# FN:  829

# %%
# Evaluation of the performance of clustering using Rand Index
rand_index = (TP + TN) / (TP + TN + FP + FN)
print('Rand Index Value: ', rand_index)
# Out:
# Rand Index Value:  0.9110010791595252

# %% [markdown]
# Since most of the pairs of issues should not be in the same cluster (since the epics contain very small amount of sub-issues), it might not be the best idea to use the Rand Index for evaluating the performance of our clustering. However, it seems good.

# %%
#save the clustered data
df.to_csv('../data/clustered_data_ckeditor5.csv', index=False)
#save the epic data
epic_df.to_csv('../data/epic_data_ckeditor5.csv', index=False)

# %%
epic_df
# Out:
#    Repo Owner  Repo Name                                        Issue Title  \
# 0    ckeditor  ckeditor5  Introduce a way to reach unaccessible places (...
# 1    ckeditor  ckeditor5                              Implement list styles
# 2    ckeditor  ckeditor5  Implement ordered lists start index and revers...
# 3    ckeditor  ckeditor5  Inline images - support multiple images in a s...
# 4    ckeditor  ckeditor5          Table cell/row/column selection – stage I
# 5    ckeditor  ckeditor5                           Implement table captions
# 6    ckeditor  ckeditor5                                 Restricted editing
# 7    ckeditor  ckeditor5  Replacement of the CKEditor 4's styles dropdow...
# 8    ckeditor  ckeditor5         Table cell/row/column selection – stage II
# 9    ckeditor  ckeditor5  Table cell/row/column selection – stage III (o...
# 10   ckeditor  ckeditor5                              Migration to monorepo
# 11   ckeditor  ckeditor5  Conversion: Re-converting the entire "thing" w...
# 12   ckeditor  ckeditor5                        Monorepo migration stage II
# 13   ckeditor  ckeditor5                             Migrate to beforeInput
# 14   ckeditor  ckeditor5       Drag and drop of textual content and widgets
# 15   ckeditor  ckeditor5                     Project migration to webpack 5
# 16   ckeditor  ckeditor5                  Find and replace 29.0.0 followups
# 17   ckeditor  ckeditor5     Redesign and introduce new reconversion system
# 18   ckeditor  ckeditor5  Resolve integration issues between commands an...
# 19   ckeditor  ckeditor5                       Migrate to beforeInput vol 2
# 20   ckeditor  ckeditor5                     [Style dropdown] Stabilization
# 21   ckeditor  ckeditor5                   Migrate CKEditor 5 to TypeScript
# 22   ckeditor  ckeditor5      Migrate CKEditor 5 to TypeScript - follow-ups
# 23   ckeditor  ckeditor5  [beforeInput] Bring back basic typing support ...
# 24   ckeditor  ckeditor5  Improve editor initialization time (scenarios ...
# 25   ckeditor  ckeditor5                            Drag and Drop of blocks
# 26   ckeditor  ckeditor5  Support adjacent lists (splitting, resetting n...
# 27   ckeditor  ckeditor5              🖼️  Supporting image height attribute
# 28   ckeditor  ckeditor5                      [Style dropdown] Improvements
# 29   ckeditor  ckeditor5                       Document list feature parity
# 30   ckeditor  ckeditor5                                     List v1 sunset
# 31   ckeditor  ckeditor5  Further enhancements to the drag & drop: list ...
# 32   ckeditor  ckeditor5                        Create a custom "stale" bot
#
#                                            Issue Body       Author  \
# 0   Problem:\r\n\r\n![image](https://user-images.g...      Reinmar
# 1   The user should be able to choose the style of...      Reinmar
# 2   Beside [list styles](https://github.com/ckedit...      Reinmar
# 3   ## Is this a bug report or feature request? (c...  ateeqsuhail
# 4   We started to work on the table selection feat...      Reinmar
# 5   Tables need to be captioned. Most likely, we c...      Reinmar
# 6   ## 📝 Provide a description of the new feature\...      Reinmar
# 7   ## What? (tl;dr)\r\n\r\nCKEditor 4 offered a [...      Reinmar
# 8   This is a followup for the table selection MVP...      jodator
# 9   This is a followup for the table selection opt...      jodator
# 10  We've been using multirepo for quite some time...      Reinmar
# 11  ## Background\r\n\r\nHow does conversion work ...      Reinmar
# 12  ## Provide a description of the task\r\n\r\nIn...      mlewand
# 13  ## 📝 Provide a description of the improvement\...      Reinmar
# 14  ## 📝 Provide a description of the new feature\...    niegowski
# 15  The list below contains (I hope) all tasks req...        pomek
# 16  ## Provide a description of the task\r\n\r\nTh...      mlewand
# 17  ## EDIT (Summary of changes)\r\n\r\nYou can fi...    niegowski
# 18  This epic started with a _"Export to PDF/Word ...      Reinmar
# 19  ## 📝 Provide a description of the new feature\...         oleq
# 20  This issue aggregates bugs and improvements to...         oleq
# 21  Back in 2015 when we were bootstrapping CKEdit...      Reinmar
# 22  This issue serves as an umbrella for all the t...      arkflpc
# 23  In a course of action in https://github.com/ck...      Reinmar
# 24  ## 📝 Provide a description of the improvement\...         Mgsy
# 25  Currently, CKEditor 5 allows dragging textual ...       Witoso
# 26  ## Use cases\r\nAs a user, I want to insert co...       Witoso
# 27  # Image feature compatibility with CKEditor 4 ...       Witoso
# 28  Improvements to our [Styles plugin](https://ck...       Witoso
# 29  The goal of this initiative is to make `Docume...       Witoso
# 30  After the:\r\n\r\n*    [ ]  https://github.com...       Witoso
# 31  ## 📝 Provide a description of the improvement\...       Witoso
# 32  ## Provide a description of the task\r\n\r\nAs...        pomek
#
#                 Assignees                                           Comments  \
# 0                ['oleq']  [{'body': 'DUP reported in https://github.com/...
# 1               ['pomek']  [{'body': '@Reinmar \r\n\r\nWe also in an eed ...
# 2                      []  [{'body': 'Microsoft word has this feature use...
# 3                      []  [{'body': 'any work around/alternative for the...
# 4                      []  [{'body': 'Some POC of fake selection in table...
# 5           ['maxbarnas']  [{'body': 'I hope this is the right issue to p...
# 6     ['jodator', 'oleq']  [{'body': '## Icon\r\n\r\nTwo proposals here, ...
# 7                      []  [{'body': "One thing to consider: People use o...
# 8                      []  [{'body': 'Hi, is the cell/row/column selectio...
# 9                      []                                                 []
# 10                     []  [{'body': 'Added the [`monorepo-mock`](https:/...
# 11                     []  [{'body': "Another doubt that came to my mind:...
# 12                     []                                                 []
# 13               ['oleq']  [{'body': "Order of things:\n1. In the beginni...
# 14          ['niegowski']  [{'body': '![](https://user-images.githubuserc...
# 15              ['pomek']  [{'body': "Regarding the documentation:\r\n\r\...
# 16                     []  [{'body': 'I did iterative merge to `master` w...
# 17          ['niegowski']  [{'body': 'The `elementToStructure` PoC is now...
# 18                     []  [{'body': 'List of issues closed in this Epic:...
# 19  ['oleq', 'niegowski']  [{'body': '@oleq Will this also address #2045?...
# 20                     []  [{'body': 'Should [#13341](https://github.com/...
# 21                     []  [{'body': "> *   Once again I'd like to thank ...
# 22                     []  [{'body': '## Replace "export type" by "export...
# 23          ['niegowski']  [{'body': "Let's try to approach this in 3 sta...
# 24                     []  [{'body': 'The improvement should be for inlin...
# 25                     []  [{'body': 'Further enhancements extracted to t...
# 26                     []  [{'body': 'Example #1\r\n```html\r\n<p>\r\n  L...
# 27       ['mmotyczynska']  [{'body': 'Questions:\n* non intuitive when se...
# 28                     []  [{'body': "Drupal uses the official `Image` pl...
# 29                     []                                                 []
# 30                     []                                                 []
# 31                     []                                                 []
# 32                     []  [{'body': 'Epic branch: https://github.com/cke...
#
#                                                Labels Issue State  \
# 0   ['type:bug', 'type:improvement', 'type:feature...      CLOSED
# 1   ['type:feature', 'package:list', 'support:2', ...      CLOSED
# 2   ['type:feature', 'package:list', 'support:2', ...      CLOSED
# 3   ['type:feature', 'package:image', 'support:2',...      CLOSED
# 4           ['type:feature', 'package:table', 'Epic']      CLOSED
# 5   ['type:feature', 'package:table', 'support:2',...      CLOSED
# 6   ['type:feature', 'package:restricted-editing',...      CLOSED
# 7   ['type:feature', 'support:2', 'Epic', 'squad:c...      CLOSED
# 8                           ['package:table', 'Epic']      CLOSED
# 9           ['type:feature', 'package:table', 'Epic']      CLOSED
# 10                       ['type:improvement', 'Epic']      CLOSED
# 11  ['resolution:duplicate', 'type:improvement', '...      CLOSED
# 12              ['type:task', 'Epic', 'squad:devops']      CLOSED
# 13  ['resolution:duplicate', 'type:improvement', '...      CLOSED
# 14  ['type:feature', 'package:clipboard', 'domain:...      CLOSED
# 15  ['type:task', 'Epic', 'bc:major', 'squad:devops']      CLOSED
# 16  ['type:improvement', 'type:task', 'Epic', 'squ...      CLOSED
# 17  ['type:feature', 'package:engine', 'support:2'...      CLOSED
# 18         ['type:improvement', 'Epic', 'squad:core']      CLOSED
# 19  ['type:feature', 'package:engine', 'package:ty...      CLOSED
# 20  ['Epic', 'squad:core', 'resolution:resolved', ...      CLOSED
# 21  ['type:task', 'Epic', 'domain:dx', 'squad:core...      CLOSED
# 22                ['Epic', 'squad:core', 'domain:ts']        OPEN
# 23  ['type:task', 'domain:typing/ime', 'Epic', 'sq...      CLOSED
# 24  ['type:improvement', 'package:ui', 'support:2'...      CLOSED
# 25             ['domain:ui/ux', 'Epic', 'squad:core']      CLOSED
# 26  ['type:improvement', 'package:list', 'Epic', '...      CLOSED
# 27  ['package:image', 'domain:ui/ux', 'Epic', 'squ...      CLOSED
# 28            ['Epic', 'squad:core', 'package:style']        OPEN
# 29                ['type:task', 'Epic', 'squad:core']      CLOSED
# 30                             ['Epic', 'squad:core']        OPEN
# 31         ['type:improvement', 'Epic', 'squad:core']        OPEN
# 32  ['type:task', 'Epic', 'squad:devops', 'package...        OPEN
#
#     Issue Number                                         References
# 0          407.0                                              [331]
# 1         1031.0                                             [1028]
# 2         1032.0                                             [1031]
# 3         2052.0                                       [8666, 8712]
# 4         3202.0  [6347, 6151, 6353, 6128, 6346, 6343, 6284, 611...
# 5         3204.0                                              [610]
# 6         5683.0                                       [5804, 5802]
# 7         5700.0                                        [648, 3416]
# 8         6285.0   [6357, 3267, 6521, 6500, 6401, 6123, 6406, 6382]
# 9         6297.0   [6122, 6453, 6446, 6120, 6121, 6115, 6769, 6631]
# 10        6466.0                     [6477, 6476, 6478, 6480, 6534]
# 11        6510.0                                       [1589, 6506]
# 12        6746.0                                             [6479]
# 13        7462.0  [7999, 8008, 8009, 8001, 8012, 8013, 7997, 799...
# 14        9128.0                                             [2664]
# 15        9799.0                                             [6770]
# 16       10024.0                 [10146, 10001, 9934, 10040, 10014]
# 17       10294.0                                            [11268]
# 18       10676.0                                            [10493]
# 19       11438.0                                            [11904]
# 20       11574.0  [11581, 11588, 11590, 11578, 11580, 11607, 115...
# 21       11704.0                                        [504, 1415]
# 22       12027.0  [11723, 11888, 13434, 12763, 13855, 12853, 138...
# 23       12058.0                                     [12058, 11438]
# 24       12592.0                                     [12890, 12682]
# 25       13933.0  [14640, 14831, 14709, 14734, 14645, 14646, 150...
# 26       13945.0                                            [12738]
# 27       14146.0  [14357, 14532, 14557, 14202, 14366, 14531, 515...
# 28       14274.0  [14372, 11577, 13341, 12777, 12625, 14216, 137...
# 29       14632.0                       [12466, 14663, 11620, 14634]
# 30       15037.0                                     [14942, 14632]
# 31       15110.0  [14711, 14739, 14641, 14643, 14712, 14940, 147...
# 32       15399.0                       [15403, 15402, 15400, 15401]
